# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://www.pib.gov.in/PressReleasePage.aspx?PRID=2044754"

headers = {
"User-Agent": "Mozilla/5.0"
}

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "lxml")

tables = soup.find_all("table")

data = []

for table in tables:
    rows = table.find_all("tr")

    for row in rows[1:]:
        cols = row.find_all(["td","th"])
        cols = [c.get_text(strip=True) for c in cols]

        if len(cols) >= 2:
            data.append(cols)

df = pd.DataFrame(data)

print(df.head())

df.to_csv("seed_varieties_dataset.csv", index=False)

print("Saved: seed_varieties_dataset.csv")
# Out:
#          0     1                        2        3  \
# 0  CEREALS
# 1           Rice  CR Dhan 416 (IET 30201)  Variety
# 2           Rice   CR DHAN 810(IET 30409)  Variety
# 3           Rice   CR Dhan 108 (IET29052)  Variety
# 4           Rice      CSR 101 (IET-30827)  Variety
#
#                                                    4  \
# 0
# 1  ICAR-National Rice Research Institute,Cuttack,...
# 2  ICAR- National Rice Research Institute, Cuttac...
# 3  ICAR-National Rice Research Institute, Cuttack...
# 4  ICAR-Central Soil Salinity Research Institute,...
#
#                                                5  \
# 0                                           None
# 1               West Bengal, Maharashtra,Gujarat
# 2                     Odisha, West Bengal, Assam
# 3                                  Odisha, Bihar
# 4  Uttar Pradesh, Haryana, Tamil Nadu, Karnataka
#
#                                                    6     7
# 0                                               None  None
# 1  Suitable forcoastal saline areas,yield 48.97 q...  None
# 2  Suitable forrainfed shallow low land, yield 42...  None
# 3  Suitable for earlydirect seeded rainfed condit...  None
# 4  Suitable for irrigatedalkaline/saline stress a...  None
# Saved: seed_varieties_dataset.csv

# %%
df=pd.read_csv("..data/ ")
